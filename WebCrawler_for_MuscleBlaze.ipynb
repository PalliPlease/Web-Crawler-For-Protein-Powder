# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse

# Config
base_url = "https://www.muscleblaze.com"
LIMIT = 100  #adjust
to_visit = [base_url]
visited_urls = set()
products = []
seen_products = set()

def crawler(verbose=True):
    crawl_count = 0

    while to_visit and crawl_count < LIMIT:
        current_url = to_visit.pop()
        print(f'Crawling: {current_url}')

        if current_url in visited_urls:
            continue

        try:
            response = requests.get(current_url, timeout=10)
            soup = BeautifulSoup(response.content, "html.parser")
        except Exception as e:
            print(f"Failed to fetch {current_url}: {e}")
            continue

        visited_urls.add(current_url)
        crawl_count += 1

        product_blocks = soup.find_all("div", class_="variant-container")
        for block in product_blocks:
            try:
                # --- Extract Title ---
                info_elem = block.find("div", class_="info")
                brand = info_elem.get_text(strip=True) if info_elem else ""

                flav_elem = block.find("span", class_="flavor-wt")
                flavor = flav_elem.get_text(strip=True) if flav_elem else ""

                title = f"{brand} | {flavor}".strip()

                # --- Extract Price ---
                price_elem = block.find("div", class_="offer-price")
                price = price_elem.get_text(strip=True) if price_elem else "N/A"

                # --- Extract Product URL ---
                a_tag = block.find("a", class_="float-wrapper", href=True)
                product_url = urljoin(base_url, a_tag["href"]) if a_tag else "N/A"

                # --- Extract Image URL ---
                image_container = block.find("div", class_="image-container")
                img_tag = image_container.find("img") if image_container else None
                img_url = urljoin(base_url, img_tag.get("data-original", img_tag.get("src", ""))) if img_tag else "N/A"


                # --- Unique Product Check ---
                unique_key = (title, price)
                if unique_key not in seen_products:
                    products.append({
                        "name": title,
                        "price": price,
                        "url": product_url,
                        "img": img_url
                    })
                    seen_products.add(unique_key)
                    if verbose:
                        print(f"{title} | {price} | {product_url} | {img_url}")

            except Exception as e:
                print(f"Error extracting product from {current_url}: {e}")

        # --- Find and Queue New URLs ---
        for link in soup.find_all('a', href=True):
            href = link['href']
            full_url = urljoin(base_url, href)
            if urlparse(full_url).netloc == urlparse(base_url).netloc:
                if full_url not in visited_urls and full_url not in to_visit:
                    to_visit.append(full_url)

    print(f"\nCrawling complete. Visited {crawl_count} pages.")
    print(f"Total Unique Products Scraped: {len(products)}")

# Run the crawler
crawler(False)
# Out:
# Crawling: https://www.muscleblaze.com
# Crawling: https://www.muscleblaze.com/sale/oats-range?itracker=w:home|top-banner-slider|;p:6|;e:122893|;
# Crawling: https://www.muscleblaze.com/sv/muscleblaze-high-protein-oats/SP-98284?navKey=VRNT-183068
# Crawling: https://www.muscleblaze.com/loyality?itracker=w:|pdp|;c:loyality|;
# Crawling: https://www.muscleblaze.com/categories/fit-foods/oats-and-cereals?navKey=CL-5718&itracker=w:||;
# Crawling: https://www.muscleblaze.com/categories/pre-post-workout?navKey=CL-1709
# Crawling: https://www.muscleblaze.com/categories/pre-post-workout/pre-workout?navKey=CL-5710
# Crawling: https://www.muscleblaze.com/categories/pre-post-workout/creatine?navKey=CL-5714
# Crawling: https://www.muscleblaze.com/categories/pre-post-workout/bcaa-n-eaa?navKey=CL-5712
# Crawling: https://www.muscleblaze.com/categories/fit-foods/protein-bars?navKey=CL-5722
# Crawling: https://www.muscleblaze.com/categories/proteins/whey-proteins?navKey=CL-5692
# Crawling: https://www.muscleblaze.com/categories/gainers/weight-gainer?navKey=CL-5708
# Crawling: https://www.muscleblaze.com/sv/muscleblaze-weight-gainer-with-added-digezyme/SP-43383?navKey=VRNT-78610&itracker=w:menuLanding||;e:78610|;
# Crawling: https://www.muscleblaze.com/categories/gainers?navKey=CL-1708&itracker=w:||;
# Crawling: https://www.muscleblaze.com/categories/vitamin-supplements/fish-oil?navKey=CL-5740
# Crawling: https://www.muscleblaze.com/pk/muscleblaze-fish-oil-1000-mg-90-capsules-pack-of-2?navKey=PA-126298&itracker=w:menuLanding||;e:126298|;
# Crawling: https://www.muscleblaze.com/sv/muscleblaze-omega-3-fish-oil-1000-mg-with-180mg-epa-and-120mg-dha/SP-36756?navKey=VRNT-90655
# Crawling: https://www.muscleblaze.com/categories/vitamin-supplements/fish-oil?navKey=CL-5740&itracker=w:||;
# Crawling: https://www.muscleblaze.com/sv/muscleblaze-omega-3-fish-oil-1000-mg-with-180mg-epa-and-120mg-dha/SP-36756?navKey=VRNT-152815&itracker=w:menuLanding||;e:152815|;
# Crawling: https://www.muscleblaze.com/sv/muscleblaze-omega-3-fish-oil-1000-mg-with-180mg-epa-and-120mg-dha/SP-36756?navKey=VRNT-79667&itracker=w:menuLanding||;e:79667|;
# Crawling: https://www.muscleblaze.com/sv/muscleblaze-omega-3-fish-oil-1000-mg-with-180mg-epa-and-120mg-dha/SP-36756?navKey=VRNT-176804&itracker=w:menuLanding||;e:176804|;
# Crawling: https://www.muscleblaze.com/sv/muscleblaze-omega-3-fish-oil-gold-3x-triple-strength-epa-n-dha/SP-61827?navKey=VRNT-154513&itracker=w:menuLanding||;e:154513|;
# Crawling: https://www.muscleblaze.com/sv/muscleblaze-omega-3-fish-oil-1000-mg-with-180mg-epa-and-120mg-dha/SP-36756?navKey=VRNT-90655&itracker=w:menuLanding||;e:90655|;
# Crawling: https://www.muscleblaze.com/reviews/categories/vitamin-supplements/fish-oil?navKey=CL-5740&itracker=w:menuLanding||;
# Crawling: https://www.muscleblaze.com/categories/vitamin-supplements?navKey=CL-5736
# Crawling: https://www.muscleblaze.com/categories/ayurveda/ashwagandha?navKey=CL-5913
# Crawling: https://www.muscleblaze.com/pk/koshaveda-shilajit-pro-gold-n-ashwagandha-60-tabs-combo?navKey=PA-131239&itracker=w:menuLanding||;e:131239|;
# Crawling: https://www.muscleblaze.com/sv/koshaveda-shilajit-pro-gold-by-muscleblaze/SP-125599?navKey=VRNT-240441
# Crawling: https://www.muscleblaze.com/categories/ayurveda/shilajit?navKey=CL-5921&itracker=w:||;
# Crawling: https://www.muscleblaze.com/sv/koshaveda-shilajit-pro-drops-by-muscleblaze/SP-126853?navKey=VRNT-243695&itracker=w:menuLanding||;e:243695|;
# Crawling: https://www.muscleblaze.com/sv/koshaveda-shilajit-pro-by-muscleblaze/SP-123495?navKey=VRNT-238083&itracker=w:menuLanding||;e:238083|;
# Crawling: https://www.muscleblaze.com/sv/koshaveda-shilajit-ashwa-gold-wsg-77-by-muscleblaze/SP-126147?navKey=VRNT-241515&itracker=w:menuLanding||;e:241515|;
# Crawling: https://www.muscleblaze.com/reviews/categories/ayurveda/shilajit?navKey=CL-5921&itracker=w:menuLanding||;
# Crawling: https://www.muscleblaze.com/categories/ayurveda/shilajit?navKey=CL-5921
# Crawling: https://www.muscleblaze.com/sv/koshaveda-ayurveda-for-performance-ashwagandha-500mg/SP-81821?navKey=VRNT-153857
# Crawling: https://www.muscleblaze.com/categories/vitamin-supplements/ayurveda?navKey=CL-5756&itracker=w:||;
# Crawling: https://www.muscleblaze.com/pk/koshaveda-shilajit-pro-20g-n-ashwagandha-af-43-600mg-60-caps-combo?navKey=PA-131667&itracker=w:menuLanding||;e:131667|;
# Crawling: https://www.muscleblaze.com/sv/koshaveda-ashwagandha-af-43-600mg/SP-127945?navKey=VRNT-246193
# Crawling: https://www.muscleblaze.com/categories/ayurveda/ashwagandha?navKey=CL-5913&itracker=w:||;
# Crawling: https://www.muscleblaze.com/sv/koshaveda-shilajit-pro-by-muscleblaze/SP-123495?navKey=VRNT-235221
# Crawling: https://www.muscleblaze.com/sv/koshaveda-ashwagandha-af-43-600mg/SP-127945?navKey=VRNT-246195&itracker=w:menuLanding||;e:246195|;
# Crawling: https://www.muscleblaze.com/sv/koshaveda-ayurveda-for-performance-ashwagandha-500mg/SP-81821?navKey=VRNT-218914&itracker=w:menuLanding||;e:218914|;
# Crawling: https://www.muscleblaze.com/sv/koshaveda-ayurveda-for-performance-ashwagandha-500mg/SP-81821?navKey=VRNT-153857&itracker=w:menuLanding||;e:153857|;
# Crawling: https://www.muscleblaze.com/sv/koshaveda-summer-shilajit-by-muscleblaze/SP-122189?navKey=VRNT-232415&itracker=w:menuLanding||;e:232415|;
# Crawling: https://www.muscleblaze.com/sv/koshaveda-ashwagandha-af-43-600mg/SP-127945?navKey=VRNT-246193&itracker=w:menuLanding||;e:246193|;
# Crawling: https://www.muscleblaze.com/reviews/categories/ayurveda/ashwagandha?navKey=CL-5913&itracker=w:menuLanding||;
# Crawling: https://www.muscleblaze.com/categories/ayurveda?navKey=CL-5911
# Crawling: https://www.muscleblaze.com/categories/ayurveda/chyawanprash?navKey=CL-5915
# Crawling: https://www.muscleblaze.com/reviews/categories/ayurveda/chyawanprash?navKey=CL-5915&itracker=w:menuLanding||;
# Crawling: https://www.muscleblaze.com/categories/ayurveda/gokshura?navKey=CL-5917
# Crawling: https://www.muscleblaze.com/sv/koshaveda-tribulus-500mg-by-muscleblaze/SP-81819?navKey=VRNT-153855&itracker=w:menuLanding||;e:153855|;
# Crawling: https://www.muscleblaze.com/categories/pre-post-workout?navKey=CL-1709&itracker=w:||;
# Crawling: https://www.muscleblaze.com/sv/koshaveda-gokshura-pro-by-muscleblaze/SP-122095?navKey=VRNT-232287&itracker=w:menuLanding||;e:232287|;
# Crawling: https://www.muscleblaze.com/reviews/categories/ayurveda/gokshura?navKey=CL-5917&itracker=w:menuLanding||;
# Crawling: https://www.muscleblaze.com/categories/ayurveda/testosterone-booster?navKey=CL-5925
# Crawling: https://www.muscleblaze.com/sv/muscleblaze-milk-thistle/SP-43632?navKey=VRNT-78914&itracker=w:menuLanding||;e:78914|;
# Crawling: https://www.muscleblaze.com/categories/ayurveda?navKey=CL-5911&itracker=w:||;
# Crawling: https://www.muscleblaze.com/sv/muscleblaze-t-surge-black/SP-116636?navKey=VRNT-219898&itracker=w:menuLanding||;e:219898|;
# Crawling: https://www.muscleblaze.com/reviews/categories/ayurveda?navKey=CL-5911&itracker=w:menuLanding||;
# Crawling: https://www.muscleblaze.com/sv/muscleblaze-mb-vite-daily-multivitamin/SP-33854?navKey=VRNT-75976&itracker=w:menuLanding||;e:75976|;
# Crawling: https://www.muscleblaze.com/categories/vitamin-supplements/multivitamins?navKey=CL-5738&itracker=w:||;
# Crawling: https://www.muscleblaze.com/sv/muscleblaze-fish-oil-1000mg-n-mb-vite-multivitamin-combo/SP-84955?navKey=VRNT-188362&itracker=w:menuLanding||;e:188362|;
# Crawling: https://www.muscleblaze.com/sv/muscleblaze-mb-vite-daily-multivitamin/SP-33854?navKey=VRNT-173153&itracker=w:menuLanding||;e:173153|;
# Crawling: https://www.muscleblaze.com/sv/muscleblaze-mb-vite-daily-multivitamin/SP-33854?navKey=VRNT-79770&itracker=w:menuLanding||;e:79770|;
# Crawling: https://www.muscleblaze.com/reviews/categories/vitamin-supplements/multivitamins?navKey=CL-5738&itracker=w:menuLanding||;
# Crawling: https://www.muscleblaze.com/sv/koshaveda-shilajit-pro-gold-by-muscleblaze/SP-125599?navKey=VRNT-240441&itracker=w:menuLanding||;e:240441|;
# Crawling: https://www.muscleblaze.com/pk/muscleblaze-fish-oil-n-mb-vite-daily-multivitamin-n-ashwagandha-60-tabs-combo?navKey=PA-129077&itracker=w:menuLanding||;e:129077|;
# Crawling: https://www.muscleblaze.com/sv/muscleblaze-omega-3-fish-oil-1000-mg-with-180mg-epa-and-120mg-dha/SP-36756?navKey=VRNT-152815
# Crawling: https://www.muscleblaze.com/sv/muscleblaze-mb-vite-daily-multivitamin/SP-33854?navKey=VRNT-75976
# Crawling: https://www.muscleblaze.com/sv/koshaveda-prash-pro-by-muscleblaze/SP-124837?navKey=VRNT-238169&itracker=w:menuLanding||;e:238169|;
# Crawling: https://www.muscleblaze.com/categories/ayurveda/chyawanprash?navKey=CL-5915&itracker=w:||;
# Crawling: https://www.muscleblaze.com/sv/muscleblaze-biozyme-5-in-1-multivitamin/SP-103974?navKey=VRNT-194572&itracker=w:menuLanding||;e:194572|;
# Crawling: https://www.muscleblaze.com/pk/muscleblaze-creatine-monohydrate-creamp-100g-n-koshaveda-shilajit-pro-20g-combo?navKey=PA-130391&itracker=w:menuLanding||;e:130391|;
# Crawling: https://www.muscleblaze.com/sv/muscleblaze-creatine-monohydrate-creamp/SP-33852?navKey=VRNT-63864
# Crawling: https://www.muscleblaze.com/categories/pre-post-workout/creatine?navKey=CL-5714&itracker=w:||;
# Crawling: https://www.muscleblaze.com/sv/muscleblaze-fish-oil-1000mg-n-mb-vite-multivitamin-combo/SP-84955?navKey=VRNT-159103&itracker=w:menuLanding||;e:159103|;
# Crawling: https://www.muscleblaze.com/sv/koshaveda-shilajit-pro-by-muscleblaze/SP-123495?navKey=VRNT-235221&itracker=w:menuLanding||;e:235221|;
# Crawling: https://www.muscleblaze.com/reviews/categories/vitamin-supplements?navKey=CL-5736&itracker=w:menuLanding||;
# Crawling: https://www.muscleblaze.com/sv/muscleblaze-mass-gainer-xxl-with-complex-carbs-and-proteins-in-3:1-ratio/SP-33848?navKey=VRNT-71252&itracker=w:menuLanding||;e:71252|;
# Crawling: https://www.muscleblaze.com/pk/muscleblaze-super-gainer-xxl-2-kg-chocolate-n-creatine-monohydrate-creamp-100g-combo?navKey=PA-131687&itracker=w:menuLanding||;e:131687|;
# Crawling: https://www.muscleblaze.com/sv/muscleblaze-super-gainer-xxl-weight-gainer/SP-42633?navKey=VRNT-79071
# Crawling: https://www.muscleblaze.com/sv/muscleblaze-super-gainer-xxl-weight-gainer/SP-42633?navKey=VRNT-90661&itracker=w:menuLanding||;e:90661|;
# Crawling: https://www.muscleblaze.com/sv/muscleblaze-super-gainer-black/SP-105316?navKey=VRNT-200198&itracker=w:menuLanding||;e:200198|;
# Crawling: https://www.muscleblaze.com/sv/muscleblaze-super-gainer-xxl-weight-gainer/SP-42633?navKey=VRNT-77301&itracker=w:menuLanding||;e:77301|;
# Crawling: https://www.muscleblaze.com/sv/muscleblaze-super-gainer-xxl-weight-gainer/SP-42633?navKey=VRNT-79071&itracker=w:menuLanding||;e:79071|;
# Crawling: https://www.muscleblaze.com/sv/muscleblaze-super-gainer-xxl-weight-gainer/SP-42633?navKey=VRNT-91389&itracker=w:menuLanding||;e:91389|;
# Failed to fetch https://www.muscleblaze.com/sv/muscleblaze-super-gainer-xxl-weight-gainer/SP-42633?navKey=VRNT-91389&itracker=w:menuLanding||;e:91389|;: HTTPSConnectionPool(host='www.muscleblaze.com', port=443): Read timed out. (read timeout=10)
# Crawling: https://www.muscleblaze.com/pk/muscleblaze-super-gainer-black-1-kg-n-creatine-monohydrate-creamp-0dot22-lb-combo?navKey=PA-127862&itracker=w:menuLanding||;e:127862|;
# Crawling: https://www.muscleblaze.com/sv/muscleblaze-super-gainer-black/SP-105316?navKey=VRNT-197066
# Crawling: https://www.muscleblaze.com/sv/muscleblaze-weight-gainer-with-added-digezyme/SP-43383?navKey=VRNT-78523&itracker=w:menuLanding||;e:78523|;
# Crawling: https://www.muscleblaze.com/sv/muscleblaze-weight-gainer-with-added-digezyme/SP-43383?navKey=VRNT-103805&itracker=w:menuLanding||;e:103805|;
# Crawling: https://www.muscleblaze.com/sv/muscleblaze-weight-gainer-with-added-digezyme/SP-43383?navKey=VRNT-132387&itracker=w:menuLanding||;e:132387|;
# Crawling: https://www.muscleblaze.com/sv/muscleblaze-weight-gainer-with-added-digezyme/SP-43383?navKey=VRNT-79072&itracker=w:menuLanding||;e:79072|;
# Crawling: https://www.muscleblaze.com/sv/muscleblaze-super-gainer-black/SP-105316?navKey=VRNT-232193&itracker=w:menuLanding||;e:232193|;
# Crawling: https://www.muscleblaze.com/reviews/categories/gainers?navKey=CL-1708&itracker=w:menuLanding||;
# Crawling: https://www.muscleblaze.com/categories/gainers?navKey=CL-1708
# Crawling: https://www.muscleblaze.com/sv/muscleblaze-super-gainer-xxl-weight-gainer/SP-42633?navKey=VRNT-91389&itracker=w:menuLanding||;e:91389|;
# Crawling: https://www.muscleblaze.com/sv/muscleblaze-biozyme-performance-whey/SP-88093?navKey=VRNT-165145&itracker=w:menuLanding||;e:165145|;
# Crawling: https://www.muscleblaze.com/categories/proteins/whey-proteins?navKey=CL-5692&itracker=w:||;
# Crawling: https://www.muscleblaze.com/sv/muscleblaze-biozyme-whey-pr/SP-122029?navKey=VRNT-249463&itracker=w:menuLanding||;e:249463|;
# Crawling: https://www.muscleblaze.com/sv/muscleblaze-biozyme-gold-100-whey/SP-130031?navKey=VRNT-252445&itracker=w:menuLanding||;e:252445|;
# Crawling: https://www.muscleblaze.com/sv/muscleblaze-biozyme-performance-whey/SP-88093?navKey=VRNT-174838&itracker=w:menuLanding||;e:174838|;
#
# Crawling complete. Visited 100 pages.
# Total Unique Products Scraped: 101

# %%
import pandas as pd
df = pd.DataFrame(products)
df
# Out:
#                                                   name   price  \
# 0    MuscleBlaze High Protein Oats, 2 kg, Dark Choc...  ₹1,199
# 1    MuscleBlaze High Protein Oats, 1 kg, Dark Choc...    ₹649
# 2     MuscleBlaze High Protein Oats, 1 kg, Unflavoured    ₹499
# 3    MuscleBlaze High Protein Oats, 1 kg, Fruit & S...    ₹649
# 4          MuscleBlaze Instant Oats, 1 kg, Unflavoured    ₹275
# ..                                                 ...     ...
# 96   MuscleBlazeBiozyme 5 in 1 Multivitamin, 90 tab...    ₹949
# 97   MuscleBlazeMB-VITE Daily Multivitamin, for Enh...    ₹949
# 98   MuscleBlazeMB-VITE Daily Multivitamin, for Enh...    ₹329
# 99   MuscleBlazeFish Oil 1000mg & MB-Vite Multivita...    ₹899
# 100  MuscleBlazeFish Oil 1000mg & MB-Vite Multivita...    ₹599
#
#                                                    url  \
# 0                                                  N/A
# 1                                                  N/A
# 2                                                  N/A
# 3                                                  N/A
# 4                                                  N/A
# ..                                                 ...
# 96   https://www.muscleblaze.com/sv/muscleblaze-bio...
# 97   https://www.muscleblaze.com/sv/muscleblaze-mb-...
# 98   https://www.muscleblaze.com/sv/muscleblaze-mb-...
# 99   https://www.muscleblaze.com/sv/muscleblaze-fis...
# 100  https://www.muscleblaze.com/sv/muscleblaze-fis...
#
#                                                    img
# 0    https://img10.hkrtcdn.com/30236/prd_3023529-Mu...
# 1    https://img8.hkrtcdn.com/39672/prd_3967117-Mus...
# 2    https://img6.hkrtcdn.com/29836/prd_2983545_c_s...
# 3    https://img10.hkrtcdn.com/39607/prd_3960649-Mu...
# 4    https://img8.hkrtcdn.com/39080/prd_3907967-Mus...
# ..                                                 ...
# 96   https://img4.hkrtcdn.com/35430/prd_3542923-Mus...
# 97   https://img8.hkrtcdn.com/40262/prd_4026127-Mus...
# 98   https://img2.hkrtcdn.com/30875/prd_3087491-Mus...
# 99   https://img4.hkrtcdn.com/40259/prd_4025883-Mus...
# 100  https://img6.hkrtcdn.com/34714/prd_3471385_c_s...
#
# [101 rows x 4 columns]

# %%
def product_lookup(dataframe, name_lookup):
    df = pd.DataFrame(dataframe).copy()

    # Remove rs, commas and spaces
    df['price'] = (
        df['price']
        .astype(str)
        .str.replace("₹", "", regex=False)
        .str.replace(",", "", regex=False)
        .str.replace(" ", "", regex=False)
        .astype(int)
    )

    result = df[df['name'].str.contains(name_lookup, case=False, na=False)].sort_values('price')
    return result.reset_index(drop=True)

# %%
a = product_lookup(df, 'Protein')

# %%
a.img
# Out:
# 0     https://img4.hkrtcdn.com/31085/prd_3108483-Mus...
# 1     https://img4.hkrtcdn.com/31085/prd_3108483-Mus...
# 2     https://img10.hkrtcdn.com/38703/prd_3870289-Mu...
# 3     https://img8.hkrtcdn.com/31056/prd_3105507-Mus...
# 4     https://img3.hkrtcdn.com/22853/prd_2285202-Mus...
# 5     https://img6.hkrtcdn.com/29836/prd_2983545_c_s...
# 6     https://img6.hkrtcdn.com/29836/prd_2983545_c_s...
# 7     https://img10.hkrtcdn.com/39607/prd_3960649-Mu...
# 8     https://img8.hkrtcdn.com/39672/prd_3967117-Mus...
# 9     https://img10.hkrtcdn.com/39607/prd_3960649-Mu...
# 10    https://img8.hkrtcdn.com/39672/prd_3967117-Mus...
# 11    https://img9.hkrtcdn.com/22852/prd_2285188-Mus...
# 12    https://img2.hkrtcdn.com/35786/prd_3578531-Mus...
# 13    https://img10.hkrtcdn.com/35963/prd_3596259-Mu...
# 14    https://img4.hkrtcdn.com/35871/pck_3587003_c_s...
# 15    https://img10.hkrtcdn.com/30236/prd_3023529-Mu...
# 16    https://img10.hkrtcdn.com/30236/prd_3023529-Mu...
# 17    https://img2.hkrtcdn.com/30239/pck_3023841_c_s...
# 18    https://img10.hkrtcdn.com/39672/prd_3967129-Mu...
# 19    https://img10.hkrtcdn.com/30612/prd_3061189-Mu...
# Name: img, dtype: object
